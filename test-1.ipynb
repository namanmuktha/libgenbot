# %%
import os
import subprocess
from libgen.scraper import Scraper

# Function to convert files to PDF using Calibre
def convert_to_pdf(input_file, output_pdf):
    print(f"Converting {input_file} to {output_pdf}...")
    extension = input_file.split('.')[-1].lower()
    if extension in ['mobi', 'epub', 'djvu', 'docx']:
        command = f"/Applications/calibre.app/Contents/MacOS/ebook-convert '{input_file}' '{output_pdf}'"
        result = subprocess.run(command, shell=True, capture_output=True, text=True)
        if result.returncode == 0:
            print(f"Converted {input_file} to PDF as {output_pdf}")
        else:
            print(f"Error in conversion: {result.stderr.strip()}")
    else:
        print(f"No conversion required for {input_file}, already in PDF format.")
    return output_pdf

# Function to download and convert the book if necessary
def download_book(book, output_dir, downloaded_titles):
    os.makedirs(output_dir, exist_ok=True)

    output_file = os.path.join(output_dir, f"{book['name']}.{book['format'].lower()}")
    
    if book['name'] in downloaded_titles:
        print(f"Skipping already downloaded book: {book['name']}")
        return

    print(f"Downloading: {book['name']}")

    download_successful = scraper.download(book['link'], output_path=output_file)
    
    if download_successful:
        print(f"Downloaded: {output_file}")
        if book['format'].lower() != "pdf":
            output_pdf = os.path.join(output_dir, f"{book['name']}.pdf")
            convert_to_pdf(output_file, output_pdf)
        downloaded_titles.add(book['name'])
    else:
        print(f"Download failed for: {book['name']}")

# Function to filter and prioritize books
def filter_books(books):
    unique_books = {}
    
    for book in books:
        title = book['name']
        if title not in unique_books:
            unique_books[title] = book
        else:
            existing_book = unique_books[title]
            if (book['year'] > existing_book['year'] and book['format'].lower() == 'pdf') or \
               (book['format'].lower() == 'pdf' and existing_book['format'].lower() != 'pdf'):
                unique_books[title] = book

    return list(unique_books.values())

# Initialize the scraper
scraper = Scraper()

# Search for books based on user input
query = input("Enter the book title or query: ")
books = scraper.get_data(query)

# Filter the books
filtered_books = filter_books(books)

# Display the filtered books with an index for user selection
for index, book in enumerate(filtered_books):
    print(f"{index + 1}. {book['name']} ({book['year']}) - {book['format']}")

# Ask user to select the books they want to download
selection = input("Enter the numbers of the books to download (comma-separated, e.g., 1,3,5): ")
selected_indices = [int(x.strip()) - 1 for x in selection.split(',')]

# Validate the selected indices
selected_books = [filtered_books[i] for i in selected_indices if 0 <= i < len(filtered_books)]

# Download the selected books
downloaded_titles = set()
for book in selected_books:
    download_book(book, output_dir="downloads", downloaded_titles=downloaded_titles)

print("All selected books have been processed.")
# Out:
# 1. Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781 (2020) - pdf
# 2. Hands-On Machine Learning with TensorFlow.js: A guide to building ML applications integrated with web technology using the TensorFlow.js library 9781838821739, 1838821732 (2019) - pdf
# 3. Hands-On Artificial Intelligence on Amazon Web Services: Decrease the time to market for AI and ML applications with the power of AWS 9781789531473, 9781789534146 (2019) - epub
# 4. Hands-On ML Projects with OpenCV: Master Computer Vision and Machine Learning Using OpenCV and Python 9789388590877 (2023) - epub
# 5. GoLang for Machine Learning: A Hands-on-Guide to Building Efficient, Smart and Scalable ML Models with Go Programming (2024) - pdf
# Downloading: Hands-On Artificial Intelligence on Amazon Web Services: Decrease the time to market for AI and ML applications with the power of AWS 9781789531473, 9781789534146
# Downloading: downloads/Hands-On Artificial Intelligence on Amazon Web Services: Decrease the time to market for AI and ML applications with the power of AWS 9781789531473, 9781789534146.epub:   0%|          | 18.3k/18.3M [10:19<176:06:03, 30.2B/s]
# Downloaded: downloads/Hands-On Artificial Intelligence on Amazon Web Services: Decrease the time to market for AI and ML applications with the power of AWS 9781789531473, 9781789534146.epub
# Converting downloads/Hands-On Artificial Intelligence on Amazon Web Services: Decrease the time to market for AI and ML applications with the power of AWS 9781789531473, 9781789534146.epub to downloads/Hands-On Artificial Intelligence on Amazon Web Services: Decrease the time to market for AI and ML applications with the power of AWS 9781789531473, 9781789534146.pdf...
# Converted downloads/Hands-On Artificial Intelligence on Amazon Web Services: Decrease the time to market for AI and ML applications with the power of AWS 9781789531473, 9781789534146.epub to PDF as downloads/Hands-On Artificial Intelligence on Amazon Web Services: Decrease the time to market for AI and ML applications with the power of AWS 9781789531473, 9781789534146.pdf
# All selected books have been processed.

# %% [markdown]
# Multithreading or processing

# %%
import os
import subprocess
from libgen.scraper import Scraper
from concurrent.futures import ThreadPoolExecutor, as_completed
import time

# Function to convert files to PDF using Calibre
def convert_to_pdf(input_file, output_pdf):
    print(f"Converting {input_file} to {output_pdf}...")
    extension = input_file.split('.')[-1].lower()
    if extension in ['mobi', 'epub', 'djvu', 'docx']:
        command = f"/Applications/calibre.app/Contents/MacOS/ebook-convert '{input_file}' '{output_pdf}'"
        result = subprocess.run(command, shell=True, capture_output=True, text=True)
        if result.returncode == 0:
            print(f"Converted {input_file} to PDF as {output_pdf}")
        else:
            print(f"Error in conversion: {result.stderr.strip()}")
    else:
        print(f"No conversion required for {input_file}, already in PDF format.")
    return output_pdf

# Function to download and convert the book if necessary
def download_book(book, output_dir, downloaded_titles, retries=3):
    os.makedirs(output_dir, exist_ok=True)
    output_file = os.path.join(output_dir, f"{book['name']}.{book['format'].lower()}")
    
    if book['name'] in downloaded_titles:
        print(f"Skipping already downloaded book: {book['name']}")
        return

    print(f"Downloading: {book['name']}")

    attempt = 0
    while attempt < retries:
        try:
            # Download the book
            download_successful = scraper.download(book['link'], output_path=output_file)
            if download_successful:
                print(f"Downloaded: {output_file}")
                # Convert to PDF if necessary
                if book['format'].lower() != "pdf":
                    output_pdf = os.path.join(output_dir, f"{book['name']}.pdf")
                    convert_to_pdf(output_file, output_pdf)
                downloaded_titles.add(book['name'])
                break  # Break out of the loop if download succeeds
            else:
                raise Exception("Download failed.")

        except Exception as e:
            print(f"Error downloading {book['name']}: {e}")
            attempt += 1
            if attempt < retries:
                print(f"Retrying... ({attempt}/{retries})")
                time.sleep(2)  # Adding a short delay before retrying
            else:
                print(f"Failed to download {book['name']} after {retries} attempts.")
                with open("download_errors.log", "a") as log_file:
                    log_file.write(f"{book['name']} - {e}\n")

# Function to filter and prioritize books
def filter_books(books):
    unique_books = {}
    
    for book in books:
        title = book['name']
        if title not in unique_books:
            unique_books[title] = book
        else:
            existing_book = unique_books[title]
            if (book['year'] > existing_book['year'] and book['format'].lower() == 'pdf') or \
               (book['format'].lower() == 'pdf' and existing_book['format'].lower() != 'pdf'):
                unique_books[title] = book

    return list(unique_books.values())

# Function to download books using threading
def download_books_concurrently(selected_books, output_dir):
    downloaded_titles = set()

    # Using ThreadPoolExecutor to parallelize downloads
    with ThreadPoolExecutor(max_workers=4) as executor:
        future_to_book = {executor.submit(download_book, book, output_dir, downloaded_titles): book for book in selected_books}
        
        # Monitor the progress of downloads
        for future in as_completed(future_to_book):
            book = future_to_book[future]
            try:
                future.result()
                print(f"Successfully downloaded: {book['name']}")
            except Exception as exc:
                print(f"{book['name']} generated an exception: {exc}")

# Initialize the scraper
scraper = Scraper()

# Search for books based on user input
query = input("Enter the book title or query: ")
books = scraper.get_data(query)

# Filter the books
filtered_books = filter_books(books)

# Display the filtered books with an index for user selection
for index, book in enumerate(filtered_books):
    print(f"{index + 1}. {book['name']} ({book['year']}) - {book['format']}")

# Ask user to select the books they want to download
selection = input("Enter the numbers of the books to download (comma-separated, e.g., 1,3,5): ")
selected_indices = [int(x.strip()) - 1 for x in selection.split(',')]

# Validate the selected indices
selected_books = [filtered_books[i] for i in selected_indices if 0 <= i < len(filtered_books)]

# Download the selected books concurrently
download_books_concurrently(selected_books, output_dir="downloads")

print("All selected books have been processed.")
# Out:
# 1. Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781 (2020) - pdf
# 2. Hands-On Machine Learning with TensorFlow.js: A guide to building ML applications integrated with web technology using the TensorFlow.js library 9781838821739, 1838821732 (2019) - pdf
# 3. Hands-On Artificial Intelligence on Amazon Web Services: Decrease the time to market for AI and ML applications with the power of AWS 9781789531473, 9781789534146 (2019) - epub
# 4. Hands-On ML Projects with OpenCV: Master Computer Vision and Machine Learning Using OpenCV and Python 9789388590877 (2023) - epub
# 5. GoLang for Machine Learning: A Hands-on-Guide to Building Efficient, Smart and Scalable ML Models with Go Programming (2024) - pdf
# Downloading: GoLang for Machine Learning: A Hands-on-Guide to Building Efficient, Smart and Scalable ML Models with Go ProgrammingDownloading: Hands-On Artificial Intelligence on Amazon Web Services: Decrease the time to market for AI and ML applications with the power of AWS 9781789531473, 9781789534146
# Downloading: Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781
#
# Error downloading Hands-On Artificial Intelligence on Amazon Web Services: Decrease the time to market for AI and ML applications with the power of AWS 9781789531473, 9781789534146: Download failed.
# Retrying... (1/3)
# Error downloading GoLang for Machine Learning: A Hands-on-Guide to Building Efficient, Smart and Scalable ML Models with Go Programming: Download failed.
# Retrying... (1/3)
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:   1%|          | 193k/18.3M [00:01<01:24, 226kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:   1%|▏         | 239k/18.3M [00:01<01:15, 253kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:   2%|▏         | 298k/18.3M [00:01<01:09, 270kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:   2%|▏         | 340k/18.3M [00:01<01:09, 272kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:   2%|▏         | 422k/18.3M [00:01<00:52, 361kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:   2%|▏         | 461k/18.3M [00:01<00:55, 336kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:   3%|▎         | 533k/18.3M [00:02<00:56, 331kB/s]
#
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:   3%|▎         | 612k/18.3M [00:03<03:18, 93.8kB/s]
#
#
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:   3%|▎         | 627k/18.3M [00:03<04:20, 71.3kB/s]
#
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:   4%|▎         | 661k/18.3M [00:04<04:29, 68.7kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:   4%|▎         | 696k/18.3M [00:04<03:26, 89.7kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:   4%|▍         | 713k/18.3M [00:04<03:09, 97.8kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:   4%|▍         | 727k/18.3M [00:05<02:56, 105kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:   4%|▍         | 739k/18.3M [00:05<05:17, 58.1kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:   4%|▍         | 757k/18.3M [00:05<04:37, 66.5kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:   4%|▍         | 766k/18.3M [00:06<05:08, 59.7kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:   4%|▍         | 774k/18.3M [00:06<05:00, 61.3kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:   4%|▍         | 802k/18.3M [00:06<03:42, 82.8kB/s]
#
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:   4%|▍         | 832k/18.3M [00:06<02:31, 121kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:   5%|▍         | 845k/18.3M [00:06<02:31, 121kB/s]
#
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:   5%|▍         | 858k/18.3M [00:06<03:38, 83.8kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:   5%|▍         | 885k/18.3M [00:07<03:09, 96.8kB/s]
#
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:   5%|▍         | 905k/18.3M [00:07<02:40, 114kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:   5%|▍         | 932k/18.3M [00:07<02:44, 111kB/s]
#
#
#
#
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:   5%|▌         | 944k/18.3M [00:08<05:59, 50.8kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:   5%|▌         | 961k/18.3M [00:08<05:50, 52.1kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:   5%|▌         | 977k/18.3M [00:08<04:36, 65.9kB/s]
#
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:   5%|▌         | 992k/18.3M [00:08<04:49, 62.8kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:   5%|▌         | 0.99M/18.3M [00:09<04:07, 73.3kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:   6%|▌         | 1.03M/18.3M [00:09<02:26, 123kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:   6%|▌         | 1.06M/18.3M [00:09<02:35, 116kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:   6%|▌         | 1.07M/18.3M [00:09<02:46, 109kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:   6%|▌         | 1.10M/18.3M [00:10<02:20, 128kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:   6%|▌         | 1.13M/18.3M [00:10<02:12, 136kB/s]
#
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:   6%|▌         | 1.14M/18.3M [00:10<04:56, 60.9kB/s]
#
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:   6%|▋         | 1.17M/18.3M [00:11<04:46, 62.9kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:   6%|▋         | 1.17M/18.3M [00:11<04:31, 66.2kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:   7%|▋         | 1.21M/18.3M [00:11<02:59, 100kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:   7%|▋         | 1.23M/18.3M [00:11<02:35, 116kB/s]
#
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:   7%|▋         | 1.25M/18.3M [00:11<02:41, 111kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:   7%|▋         | 1.26M/18.3M [00:12<02:41, 111kB/s]
#
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:   7%|▋         | 1.28M/18.3M [00:12<03:43, 79.9kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:   7%|▋         | 1.32M/18.3M [00:12<02:22, 125kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:   7%|▋         | 1.34M/18.3M [00:12<02:08, 139kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:   8%|▊         | 1.39M/18.3M [00:13<01:56, 152kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:   8%|▊         | 1.40M/18.3M [00:13<01:50, 161kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:   8%|▊         | 1.45M/18.3M [00:13<01:40, 176kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:   8%|▊         | 1.47M/18.3M [00:13<01:37, 181kB/s]
#
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:   8%|▊         | 1.49M/18.3M [00:13<02:31, 116kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:   8%|▊         | 1.52M/18.3M [00:14<02:13, 133kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:   8%|▊         | 1.55M/18.3M [00:14<01:54, 153kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:   9%|▊         | 1.58M/18.3M [00:14<01:29, 196kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:   9%|▊         | 1.60M/18.3M [00:14<01:42, 171kB/s]
#
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:   9%|▉         | 1.62M/18.3M [00:14<02:10, 135kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:   9%|▉         | 1.63M/18.3M [00:14<02:23, 122kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:   9%|▉         | 1.67M/18.3M [00:15<02:11, 133kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:   9%|▉         | 1.68M/18.3M [00:15<02:22, 122kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:   9%|▉         | 1.71M/18.3M [00:15<01:45, 165kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:   9%|▉         | 1.73M/18.3M [00:15<01:56, 149kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  10%|▉         | 1.75M/18.3M [00:15<03:00, 96.6kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  10%|▉         | 1.76M/18.3M [00:16<02:46, 105kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  10%|▉         | 1.79M/18.3M [00:16<02:28, 117kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  10%|▉         | 1.81M/18.3M [00:16<02:09, 134kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  10%|█         | 1.83M/18.3M [00:16<01:56, 149kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  10%|█         | 1.87M/18.3M [00:16<01:22, 209kB/s]
#
#
#
#
#
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  10%|█         | 1.90M/18.3M [00:17<05:13, 54.9kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  10%|█         | 1.91M/18.3M [00:18<04:29, 63.8kB/s]
#
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  11%|█         | 1.93M/18.3M [00:18<05:00, 57.3kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  11%|█         | 1.94M/18.3M [00:18<05:26, 52.6kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  11%|█         | 1.95M/18.3M [00:18<05:15, 54.5kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  11%|█         | 1.96M/18.3M [00:19<04:40, 61.3kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  11%|█         | 1.99M/18.3M [00:19<04:05, 69.8kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  11%|█         | 2.01M/18.3M [00:19<03:17, 86.9kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  11%|█         | 2.05M/18.3M [00:19<02:40, 106kB/s]
#
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  11%|█▏        | 2.07M/18.3M [00:20<02:43, 104kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  11%|█▏        | 2.09M/18.3M [00:20<02:50, 100kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  11%|█▏        | 2.10M/18.3M [00:20<02:56, 96.3kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  12%|█▏        | 2.12M/18.3M [00:20<02:49, 101kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  12%|█▏        | 2.13M/18.3M [00:20<02:36, 109kB/s]
#
#
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  12%|█▏        | 2.14M/18.3M [00:21<03:47, 74.7kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  12%|█▏        | 2.15M/18.3M [00:21<04:18, 65.7kB/s]
#
#
#
#
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  12%|█▏        | 2.16M/18.3M [00:21<08:24, 33.6kB/s]
#
#
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  12%|█▏        | 2.17M/18.3M [00:22<10:33, 26.7kB/s]
#
#
#
#
#
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  12%|█▏        | 2.19M/18.3M [00:24<14:53, 19.0kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  12%|█▏        | 2.22M/18.3M [00:24<05:49, 48.3kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  12%|█▏        | 2.24M/18.3M [00:24<04:25, 63.4kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  12%|█▏        | 2.26M/18.3M [00:24<03:04, 91.3kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  12%|█▏        | 2.28M/18.3M [00:24<03:11, 88.0kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  13%|█▎        | 2.31M/18.3M [00:24<02:20, 119kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  13%|█▎        | 2.33M/18.3M [00:25<02:17, 122kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  13%|█▎        | 2.36M/18.3M [00:25<01:46, 158kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  13%|█▎        | 2.38M/18.3M [00:25<01:34, 178kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  13%|█▎        | 2.42M/18.3M [00:25<01:18, 214kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  13%|█▎        | 2.45M/18.3M [00:25<01:07, 246kB/s]
#
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  14%|█▎        | 2.48M/18.3M [00:25<01:27, 189kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  14%|█▎        | 2.52M/18.3M [00:25<01:14, 223kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  14%|█▍        | 2.57M/18.3M [00:25<00:59, 276kB/s]
#
#
#
#
#
#
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  14%|█▍        | 2.60M/18.3M [00:26<02:41, 102kB/s]
#
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  14%|█▍        | 2.64M/18.3M [00:27<02:21, 116kB/s]
#
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  15%|█▍        | 2.67M/18.3M [00:27<02:22, 115kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  15%|█▍        | 2.69M/18.3M [00:27<02:12, 124kB/s]
#
#
#
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  15%|█▍        | 2.70M/18.3M [00:27<03:31, 77.4kB/s]
#
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  15%|█▍        | 2.72M/18.3M [00:28<03:34, 76.5kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  15%|█▍        | 2.74M/18.3M [00:28<03:01, 90.3kB/s]
#
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  15%|█▌        | 2.78M/18.3M [00:28<03:05, 87.8kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  15%|█▌        | 2.81M/18.3M [00:29<02:41, 101kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  15%|█▌        | 2.83M/18.3M [00:29<02:08, 126kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  16%|█▌        | 2.85M/18.3M [00:29<02:06, 128kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  16%|█▌        | 2.87M/18.3M [00:29<02:22, 114kB/s]
#
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  16%|█▌        | 2.90M/18.3M [00:30<02:56, 91.5kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  16%|█▌        | 2.91M/18.3M [00:30<02:39, 102kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  16%|█▌        | 2.94M/18.3M [00:30<02:02, 132kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  16%|█▌        | 2.95M/18.3M [00:30<02:08, 126kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  16%|█▌        | 2.96M/18.3M [00:30<02:07, 126kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  16%|█▌        | 2.98M/18.3M [00:30<02:14, 119kB/s]
#
#
#
#
#
#
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  16%|█▋        | 2.99M/18.3M [00:32<09:56, 27.0kB/s]
#
#
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  16%|█▋        | 3.00M/18.3M [00:32<10:25, 25.7kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  16%|█▋        | 3.00M/18.3M [00:32<09:26, 28.4kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  16%|█▋        | 3.02M/18.3M [00:32<06:55, 38.6kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  17%|█▋        | 3.04M/18.3M [00:32<04:31, 59.0kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  17%|█▋        | 3.07M/18.3M [00:33<03:05, 86.5kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  17%|█▋        | 3.08M/18.3M [00:33<02:52, 92.8kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  17%|█▋        | 3.11M/18.3M [00:33<02:17, 116kB/s]
#
#
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  17%|█▋        | 3.12M/18.3M [00:33<04:23, 60.5kB/s]
#
#
#
#
#
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  17%|█▋        | 3.13M/18.3M [00:34<06:53, 38.5kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  17%|█▋        | 3.14M/18.3M [00:34<06:26, 41.2kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  17%|█▋        | 3.15M/18.3M [00:34<05:43, 46.3kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  17%|█▋        | 3.18M/18.3M [00:35<03:26, 77.0kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  17%|█▋        | 3.20M/18.3M [00:35<03:03, 86.3kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  18%|█▊        | 3.22M/18.3M [00:35<02:19, 114kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  18%|█▊        | 3.24M/18.3M [00:35<01:59, 132kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  18%|█▊        | 3.27M/18.3M [00:35<01:39, 159kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  18%|█▊        | 3.29M/18.3M [00:35<01:32, 170kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  18%|█▊        | 3.33M/18.3M [00:35<01:16, 206kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  19%|█▊        | 3.42M/18.3M [00:36<00:57, 272kB/s]
#
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  19%|█▉        | 3.45M/18.3M [00:36<01:24, 185kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  19%|█▉        | 3.53M/18.3M [00:36<00:51, 301kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  19%|█▉        | 3.56M/18.3M [00:36<00:50, 306kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  20%|█▉        | 3.62M/18.3M [00:37<00:59, 261kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  20%|██        | 3.69M/18.3M [00:37<01:01, 250kB/s]
#
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  20%|██        | 3.72M/18.3M [00:37<01:27, 175kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  21%|██        | 3.77M/18.3M [00:37<01:03, 241kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  21%|██        | 3.80M/18.3M [00:37<01:03, 240kB/s]
#
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  21%|██        | 3.82M/18.3M [00:38<01:17, 197kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  21%|██        | 3.85M/18.3M [00:38<01:17, 196kB/s]
#
#
#
#
#
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  21%|██        | 3.87M/18.3M [00:38<02:40, 94.6kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  21%|██        | 3.88M/18.3M [00:38<02:27, 103kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  21%|██▏       | 3.90M/18.3M [00:39<02:21, 107kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  21%|██▏       | 3.92M/18.3M [00:39<02:04, 121kB/s]
#
#
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  22%|██▏       | 3.98M/18.3M [00:39<02:06, 119kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  22%|██▏       | 4.00M/18.3M [00:40<02:05, 120kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  22%|██▏       | 4.01M/18.3M [00:40<01:55, 130kB/s]
#
#
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  22%|██▏       | 4.04M/18.3M [00:40<03:27, 72.1kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  22%|██▏       | 4.05M/18.3M [00:40<03:15, 76.6kB/s]
#
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  22%|██▏       | 4.07M/18.3M [00:41<03:06, 80.0kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  22%|██▏       | 4.08M/18.3M [00:41<02:59, 83.2kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  22%|██▏       | 4.10M/18.3M [00:41<02:40, 92.8kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  22%|██▏       | 4.12M/18.3M [00:41<02:14, 111kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  23%|██▎       | 4.13M/18.3M [00:41<02:26, 102kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  23%|██▎       | 4.14M/18.3M [00:41<02:05, 118kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  23%|██▎       | 4.16M/18.3M [00:41<02:13, 111kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  23%|██▎       | 4.17M/18.3M [00:42<02:57, 83.5kB/s]
#
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  23%|██▎       | 4.19M/18.3M [00:42<02:56, 83.8kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  23%|██▎       | 4.24M/18.3M [00:42<02:12, 112kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  24%|██▎       | 4.31M/18.3M [00:43<01:26, 169kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  24%|██▍       | 4.41M/18.3M [00:44<02:45, 88.3kB/s]
#
#
#
#
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  24%|██▍       | 4.43M/18.3M [00:45<07:48, 31.1kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  24%|██▍       | 4.45M/18.3M [00:46<05:53, 41.2kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  24%|██▍       | 4.48M/18.3M [00:46<03:35, 67.5kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  25%|██▍       | 4.50M/18.3M [00:46<02:51, 84.7kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  25%|██▍       | 4.52M/18.3M [00:46<02:15, 107kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  25%|██▍       | 4.54M/18.3M [00:46<01:47, 134kB/s]
#
#
#
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  25%|██▍       | 4.56M/18.3M [00:47<02:57, 81.1kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  25%|██▍       | 4.57M/18.3M [00:47<03:51, 62.2kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  25%|██▌       | 4.58M/18.3M [00:47<03:43, 64.6kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  25%|██▌       | 4.60M/18.3M [00:47<03:10, 75.7kB/s]
#
#
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  25%|██▌       | 4.62M/18.3M [00:48<03:03, 78.2kB/s]
#
#
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  25%|██▌       | 4.63M/18.3M [00:48<04:22, 54.8kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  25%|██▌       | 4.66M/18.3M [00:48<03:44, 63.9kB/s]
#
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  25%|██▌       | 4.67M/18.3M [00:49<04:21, 54.8kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  25%|██▌       | 4.67M/18.3M [00:49<04:12, 56.7kB/s]
#
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  26%|██▌       | 4.69M/18.3M [00:49<05:15, 45.4kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  26%|██▌       | 4.69M/18.3M [00:49<04:39, 51.2kB/s]
#
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  26%|██▌       | 4.74M/18.3M [00:50<02:52, 82.5kB/s]
#
#
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  26%|██▌       | 4.75M/18.3M [00:50<04:35, 51.6kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  26%|██▌       | 4.79M/18.3M [00:50<02:36, 90.4kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  26%|██▋       | 4.84M/18.3M [00:51<01:44, 136kB/s]
#
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  27%|██▋       | 4.86M/18.3M [00:51<01:50, 127kB/s]
#
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  27%|██▋       | 4.88M/18.3M [00:51<03:03, 76.9kB/s]
#
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  27%|██▋       | 4.90M/18.3M [00:52<03:34, 65.8kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  27%|██▋       | 4.90M/18.3M [00:52<03:42, 63.3kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  27%|██▋       | 4.91M/18.3M [00:52<03:54, 60.0kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  27%|██▋       | 4.92M/18.3M [00:52<03:48, 61.5kB/s]
# ...
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  80%|████████  | 14.7M/18.3M [02:44<00:17, 216kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  81%|████████  | 14.8M/18.3M [02:44<00:15, 240kB/s]
#
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  81%|████████  | 14.8M/18.3M [02:44<00:14, 254kB/s]
#
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  81%|████████  | 14.8M/18.3M [02:44<00:17, 211kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  81%|████████  | 14.9M/18.3M [02:45<00:16, 225kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  81%|████████▏ | 14.9M/18.3M [02:45<00:16, 224kB/s]
#
#
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  81%|████████▏ | 14.9M/18.3M [02:45<00:28, 127kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  81%|████████▏ | 14.9M/18.3M [02:45<00:26, 136kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  82%|████████▏ | 15.0M/18.3M [02:45<00:24, 146kB/s]
#
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  82%|████████▏ | 15.0M/18.3M [02:45<00:27, 130kB/s]
#
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  82%|████████▏ | 15.0M/18.3M [02:46<00:35, 99.9kB/s]
#
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  82%|████████▏ | 15.0M/18.3M [02:46<00:35, 98.9kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  82%|████████▏ | 15.0M/18.3M [02:46<00:36, 94.1kB/s]
#
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  82%|████████▏ | 15.0M/18.3M [02:46<00:41, 82.6kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  82%|████████▏ | 15.0M/18.3M [02:46<00:39, 87.9kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  82%|████████▏ | 15.1M/18.3M [02:46<00:34, 99.2kB/s]
#
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  82%|████████▏ | 15.1M/18.3M [02:47<00:48, 70.1kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  82%|████████▏ | 15.1M/18.3M [02:47<00:33, 101kB/s]
#
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  83%|████████▎ | 15.1M/18.3M [02:47<00:34, 96.5kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  83%|████████▎ | 15.2M/18.3M [02:48<00:56, 59.1kB/s]
#
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  83%|████████▎ | 15.2M/18.3M [02:48<01:03, 51.7kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  83%|████████▎ | 15.2M/18.3M [02:49<01:13, 44.4kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  83%|████████▎ | 15.2M/18.3M [02:50<01:23, 39.0kB/s]
#
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  83%|████████▎ | 15.2M/18.3M [02:50<00:54, 59.3kB/s]
#
#
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  83%|████████▎ | 15.3M/18.3M [02:50<01:22, 39.1kB/s]
#
#
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  83%|████████▎ | 15.3M/18.3M [02:51<01:36, 33.2kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  83%|████████▎ | 15.3M/18.3M [02:51<01:15, 42.5kB/s]
#
#
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  83%|████████▎ | 15.3M/18.3M [02:51<01:38, 32.2kB/s]
#
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  83%|████████▎ | 15.3M/18.3M [02:52<01:57, 27.1kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  84%|████████▎ | 15.3M/18.3M [02:52<01:36, 32.9kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  84%|████████▎ | 15.3M/18.3M [02:52<01:09, 45.7kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  84%|████████▎ | 15.3M/18.3M [02:52<00:58, 54.1kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  84%|████████▍ | 15.4M/18.3M [02:52<00:34, 89.9kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  84%|████████▍ | 15.4M/18.3M [02:52<00:27, 111kB/s]
#
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  84%|████████▍ | 15.4M/18.3M [02:53<00:30, 102kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  84%|████████▍ | 15.4M/18.3M [02:53<00:21, 142kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  84%|████████▍ | 15.5M/18.3M [02:53<00:21, 142kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  84%|████████▍ | 15.5M/18.3M [02:53<00:21, 141kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  85%|████████▍ | 15.5M/18.3M [02:53<00:24, 123kB/s]
#
#
#
#
#
#
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  85%|████████▍ | 15.5M/18.3M [02:54<01:13, 40.3kB/s]
#
#
#
#
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  85%|████████▍ | 15.5M/18.3M [02:55<01:38, 30.0kB/s]
#
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  85%|████████▍ | 15.5M/18.3M [02:55<01:13, 39.8kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  85%|████████▍ | 15.5M/18.3M [02:56<01:04, 45.0kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  85%|████████▌ | 15.6M/18.3M [02:57<00:34, 80.9kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  85%|████████▌ | 15.6M/18.3M [02:57<00:30, 92.5kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  85%|████████▌ | 15.7M/18.3M [02:57<00:28, 97.0kB/s]
#
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  85%|████████▌ | 15.7M/18.3M [02:57<00:34, 81.0kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  86%|████████▌ | 15.7M/18.3M [02:57<00:33, 83.4kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  86%|████████▌ | 15.7M/18.3M [02:57<00:31, 88.3kB/s]
#
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  86%|████████▌ | 15.7M/18.3M [02:58<00:25, 106kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  86%|████████▌ | 15.7M/18.3M [02:58<00:23, 117kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  86%|████████▌ | 15.8M/18.3M [02:58<00:19, 140kB/s]
#
#
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  86%|████████▌ | 15.8M/18.3M [02:58<00:31, 84.4kB/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  86%|████████▌ | 15.8M/18.3M [02:58<00:28, 92.5kB/s]
# Downloading: downloads/GoLang for Machine Learning: A Hands-on-Guide to Building Efficient, Smart and Scalable ML Models with Go Programming.pdf:   0%|          | 19.1k/19.1M [02:57<50:31:04, 110B/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  86%|████████▋ | 15.8M/18.3M [02:59<00:22, 116kB/s]
# Downloaded: downloads/GoLang for Machine Learning: A Hands-on-Guide to Building Efficient, Smart and Scalable ML Models with Go Programming.pdf
# Successfully downloaded: GoLang for Machine Learning: A Hands-on-Guide to Building Efficient, Smart and Scalable ML Models with Go Programming
# Downloading: downloads/Hands-On Artificial Intelligence on Amazon Web Services: Decrease the time to market for AI and ML applications with the power of AWS 9781789531473, 9781789534146.epub:   0%|          | 18.3k/18.3M [03:14<55:21:45, 96.1B/s]
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:  92%|█████████▏| 16.9M/18.3M [03:15<00:29, 52.6kB/s]
# Downloaded: downloads/Hands-On Artificial Intelligence on Amazon Web Services: Decrease the time to market for AI and ML applications with the power of AWS 9781789531473, 9781789534146.epub
# Converting downloads/Hands-On Artificial Intelligence on Amazon Web Services: Decrease the time to market for AI and ML applications with the power of AWS 9781789531473, 9781789534146.epub to downloads/Hands-On Artificial Intelligence on Amazon Web Services: Decrease the time to market for AI and ML applications with the power of AWS 9781789531473, 9781789534146.pdf...
# Downloading: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf:   0%|          | 18.3k/18.3M [03:33<60:37:58, 88.0B/s]
# Downloaded: downloads/Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781.pdf
# Successfully downloaded: Hands-On Machine Learning with ML.NET: Getting started with Microsoft ML.NET to implement popular machine learning algorithms in C# 1789801788, 9781789801781
# Converted downloads/Hands-On Artificial Intelligence on Amazon Web Services: Decrease the time to market for AI and ML applications with the power of AWS 9781789531473, 9781789534146.epub to PDF as downloads/Hands-On Artificial Intelligence on Amazon Web Services: Decrease the time to market for AI and ML applications with the power of AWS 9781789531473, 9781789534146.pdf
# Successfully downloaded: Hands-On Artificial Intelligence on Amazon Web Services: Decrease the time to market for AI and ML applications with the power of AWS 9781789531473, 9781789534146
# All selected books have been processed.
